# %%
import pandas as pd

# %%
#series [1,2,3,4,6]
s=pd.Series([1,2,3,4,6],index=['A','B','D','F','H'])
s
# Out:
# A    1
# B    2
# D    3
# F    4
# H    6
# dtype: int64

# %%
s.index
# Out:
# Index(['A', 'B', 'D', 'F', 'H'], dtype='object')

# %%
s.values
# Out:
# array([1, 2, 3, 4, 6], dtype=int64)

# %%
s[3]
# Out:
# 4

# %%
s['D']
# Out:
# 3

# %%
s[1:4]
# Out:
# B    2
# D    3
# F    4
# dtype: int64

# %%
s[:]
# Out:
# A    1
# B    2
# D    3
# F    4
# H    6
# dtype: int64

# %%
s[:-1]
# Out:
# A    1
# B    2
# D    3
# F    4
# dtype: int64

# %%
s['K']=55 #s[7]  error

# %%
s
# Out:
# A     1
# B     2
# D     3
# F     4
# H     6
# K    55
# dtype: int64

# %%
s['K']
# Out:
# 55

# %%
s[2]=33
s
# Out:
# A     1
# B     2
# D    33
# F     4
# H     6
# K    55
# dtype: int64

# %%
s['A','F','B']=0
s
# Out:
# A     0
# B     0
# D    33
# F     0
# H     6
# K    55
# dtype: int64

# %%
s=s[s>6] + 2

# %%
s
# Out:
# D    35
# K    57
# dtype: int64

# %%
x=pd.Series({'a':1,'b':44,'c':3})
x
# Out:
# a     1
# b    44
# c     3
# dtype: int64

# %%
import numpy as np

# %%
arr=np.array([[11,22,33],[44,55,66],[77,88,99]])
arr
# Out:
# array([[11, 22, 33],
#        [44, 55, 66],
#        [77, 88, 99]])

# %%
df=pd.DataFrame(arr,columns=['A','B','C'],index=['g','j','k'])
df
# Out:
#     A   B   C
# g  11  22  33
# j  44  55  66
# k  77  88  99

# %%
dt=pd.DataFrame({'name':['ahmed','ali','mona'],'age':[20,30,40]},index=['a','b','c'])
dt
# Out:
#     name  age
# a  ahmed   20
# b    ali   30
# c   mona   40

# %%
data=pd.read_csv("data.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.shape
# Out:
# (569, 33)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=569, step=1)

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data.values
# Out:
# array([[842302, 'M', 17.99, ..., 0.4601, 0.1189, nan],
#        [842517, 'M', 20.57, ..., 0.275, 0.08902, nan],
#        [84300903, 'M', 19.69, ..., 0.3613, 0.08757999999999999, nan],
#        ...,
#        [926954, 'M', 16.6, ..., 0.2218, 0.0782, nan],
#        [927241, 'M', 20.6, ..., 0.4087, 0.124, nan],
#        [92751, 'B', 7.76, ..., 0.2871, 0.07039, nan]], dtype=object)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.head(20)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M        17.99         10.38          122.80     1001.0
# 1     842517         M        20.57         17.77          132.90     1326.0
# 2   84300903         M        19.69         21.25          130.00     1203.0
# 3   84348301         M        11.42         20.38           77.58      386.1
# 4   84358402         M        20.29         14.34          135.10     1297.0
# 5     843786         M        12.45         15.70           82.57      477.1
# 6     844359         M        18.25         19.98          119.60     1040.0
# 7   84458202         M        13.71         20.83           90.20      577.9
# 8     844981         M        13.00         21.82           87.50      519.8
# 9   84501001         M        12.46         24.04           83.97      475.9
# 10    845636         M        16.02         23.24          102.70      797.8
# ...

# %%
data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
data.tail(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 559  925291         B        11.51         23.93           74.52      403.5
# 560  925292         B        14.05         27.15           91.38      600.4
# 561  925311         B        11.20         29.37           70.67      386.0
# 562  925622         M        15.22         30.62          103.40      716.9
# 563  926125         M        20.92         25.09          143.00     1347.0
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
data.sample()
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 374  9013005         B        13.69         16.07           87.84      579.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 374          0.08302           0.06374         0.02556              0.02031
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 374  ...          20.21            99.16       670.6            0.1105
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 374             0.2096           0.1346               0.06987          0.3323
#
#      fractal_dimension_worst  Unnamed: 32
# 374                  0.07701          NaN
#
# [1 rows x 33 columns]

# %%
data.sample()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 558  925277         B        14.59         22.68           96.39      657.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 558          0.08473             0.133          0.1029              0.03736
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 558  ...          27.27            105.9       733.5            0.1026
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 558             0.3171           0.3662                0.1105          0.2258
#
#      fractal_dimension_worst  Unnamed: 32
# 558                  0.08004          NaN
#
# [1 rows x 33 columns]

# %%
data.sample(n=7)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 550     923748         B       10.860         21.48           68.51
# 463  911320501         B       11.600         18.36           73.88
# 470    9113778         B        9.667         18.49           61.49
# 21     8510824         B        9.504         12.44           60.34
# 416     905978         B        9.405         21.70           59.60
# 46    85713702         B        8.196         16.84           51.71
# 156    8711202         M       17.680         20.74          117.40
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 550      360.5          0.07431           0.04227         0.00000
# 463      412.7          0.08508           0.05855         0.03367
# 470      289.1          0.08946           0.06258         0.02948
# 21       273.9          0.10240           0.06492         0.02956
# 416      271.2          0.10440           0.06159         0.02047
# ...

# %%
data.sample(frac=.2)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 1      842517         M       20.570         17.77          132.90     1326.0
# 536  91979701         M       14.270         22.55           93.77      629.8
# 324  89511501         B       12.200         15.21           78.01      457.9
# 23     851509         M       21.160         23.04          137.20     1404.0
# 93     862009         B       13.450         18.30           86.60      555.1
# ..        ...       ...          ...           ...             ...        ...
# 411    905520         B       11.040         16.83           70.92      373.2
# 45     857010         M       18.650         17.60          123.70     1076.0
# 140    868999         B        9.738         11.97           61.24      288.5
# 417  90602302         M       15.500         21.08          102.90      803.1
# 306     89344         B       13.200         15.82           84.07      537.3
#
# ...

# %%
#loc & iloc

data.loc[50:300,['radius_mean','smoothness_mean']] # label or column name
# Out:
#      radius_mean  smoothness_mean
# 50         11.76          0.08637
# 51         13.64          0.07685
# 52         11.94          0.08261
# 53         18.22          0.11480
# 54         15.10          0.09056
# ..           ...              ...
# 296        10.91          0.08518
# 297        11.76          0.09968
# 298        14.26          0.06576
# 299        10.51          0.10150
# 300        19.53          0.11500
#
# [251 rows x 2 columns]

# %%
data.loc[50:300,'radius_mean':'smoothness_mean']
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean
# 50         11.76         21.60           74.72      427.9          0.08637
# 51         13.64         16.34           87.21      571.8          0.07685
# 52         11.94         18.24           75.71      437.6          0.08261
# 53         18.22         18.70          120.30     1033.0          0.11480
# 54         15.10         22.02           97.26      712.8          0.09056
# ..           ...           ...             ...        ...              ...
# 296        10.91         12.35           69.14      363.7          0.08518
# 297        11.76         18.14           75.00      431.1          0.09968
# 298        14.26         18.17           91.22      633.1          0.06576
# 299        10.51         23.09           66.85      334.2          0.10150
# 300        19.53         18.90          129.50     1217.0          0.11500
#
# [251 rows x 5 columns]

# %%
data.iloc[100:350,2:9]
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 100       13.610         24.98           88.05      582.7          0.09488
# 101        6.981         13.43           43.79      143.5          0.11700
# 102       12.180         20.52           77.22      458.7          0.08013
# 103        9.876         19.40           63.95      298.3          0.10050
# 104       10.490         19.29           67.41      336.1          0.09989
# ..           ...           ...             ...        ...              ...
# 345       10.260         14.71           66.20      321.6          0.09882
# 346       12.060         18.90           76.66      445.3          0.08386
# 347       14.760         14.74           94.87      668.7          0.08875
# 348       11.470         16.03           73.02      402.7          0.09076
# 349       11.950         14.96           77.23      426.7          0.11580
#
#      compactness_mean  concavity_mean
# ...

# %%
data.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
data.diagnosis.nunique()
# Out:
# 2

# %%
data["col4"]=data.area_mean +2

# %%
data.area_mean=data.smoothness_mean +data.perimeter_mean /2

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80   61.51840
# 1      842517         M        20.57         17.77          132.90   66.53474
# 2    84300903         M        19.69         21.25          130.00   65.10960
# 3    84348301         M        11.42         20.38           77.58   38.93250
# 4    84358402         M        20.29         14.34          135.10   67.65030
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00   71.11100
# 565    926682         M        20.13         28.25          131.20   65.69780
# 566    926954         M        16.60         28.08          108.30   54.23455
# 567    927241         M        20.60         29.33          140.10   70.16780
# 568     92751         B         7.76         24.54           47.92   24.01263
#
# ...
