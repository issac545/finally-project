# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
data=pd.read_csv("Fat_Supply_Quantity_Data.csv")
data
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
data .isnull().sum()
# Out:
# Country                         0
# Alcoholic Beverages             0
# Animal Products                 0
# Animal fats                     0
# Aquatic Products, Other         0
# Cereals - Excluding Beer        0
# Eggs                            0
# Fish, Seafood                   0
# Fruits - Excluding Wine         0
# Meat                            0
# Miscellaneous                   0
# Milk - Excluding Butter         0
# Offals                          0
# Oilcrops                        0
# Pulses                          0
# Spices                          0
# Starchy Roots                   0
# Stimulants                      0
# Sugar Crops                     0
# Sugar & Sweeteners              0
# Treenuts                        0
# Vegetal Products                0
# Vegetable Oils                  0
# Vegetables                      0
# Obesity                         3
# Undernourished                  7
# Confirmed                       6
# ...

# %%
data.fillna(method="ffill",inplace=True)

# %%
data
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
data .isnull().sum()
# Out:
# Country                         0
# Alcoholic Beverages             0
# Animal Products                 0
# Animal fats                     0
# Aquatic Products, Other         0
# Cereals - Excluding Beer        0
# Eggs                            0
# Fish, Seafood                   0
# Fruits - Excluding Wine         0
# Meat                            0
# Miscellaneous                   0
# Milk - Excluding Butter         0
# Offals                          0
# Oilcrops                        0
# Pulses                          0
# Spices                          0
# Starchy Roots                   0
# Stimulants                      0
# Sugar Crops                     0
# Sugar & Sweeteners              0
# Treenuts                        0
# Vegetal Products                0
# Vegetable Oils                  0
# Vegetables                      0
# Obesity                         0
# Undernourished                  0
# Confirmed                       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       170 non-null    object
#  1   Alcoholic Beverages           170 non-null    float64
#  2   Animal Products               170 non-null    float64
#  3   Animal fats                   170 non-null    float64
#  4   Aquatic Products, Other       170 non-null    float64
#  5   Cereals - Excluding Beer      170 non-null    float64
#  6   Eggs                          170 non-null    float64
#  7   Fish, Seafood                 170 non-null    float64
#  8   Fruits - Excluding Wine       170 non-null    float64
#  9   Meat                          170 non-null    float64
#  10  Miscellaneous                 170 non-null    float64
#  11  Milk - Excluding Butter       170 non-null    float64
# ...

# %%
x=data.loc[:85,['Recovered']]
y=data.loc[:85,['Obesity']]
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)
plt.scatter(x_train,y_train)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
xfit=data.loc[87:,['Recovered']]
yfit=data.loc[87:,['Obesity']]
yfit,xfit
# Out:
# (     Obesity
#  87      31.3
#  88      13.5
#  89       8.6
#  90      28.4
#  91      24.2
#  ..       ...
#  165     25.2
#  166      2.1
#  167     14.1
#  168      6.5
#  169     12.3
#
#  [83 rows x 1 columns],
#       Recovered
#  87    2.947062
#  88    0.126331
#  89    0.034994
#  90    4.939621
#  91    7.661551
#  ..         ...
#  165   0.424399
#  166   0.001526
#  167   0.004788
#  168   0.290524
#  169   0.190964
#
#  [83 rows x 1 columns])

# %%
yprediction=model.predict(xfit)
yprediction
# Out:
# array([[22.47444397],
#        [16.12844898],
#        [15.92296303],
#        [26.95724009],
#        [33.08095402],
#        [15.99222313],
#        [15.97769175],
#        [17.12741472],
#        [21.89740238],
#        [15.9114909 ],
#        [22.69525534],
#        [16.61762281],
#        [15.94027203],
#        [18.45352785],
#        [15.94122689],
#        [36.1818574 ],
#        [18.68473686],
#        [16.03762249],
#        [16.03762249],
#        [18.79779786],
#        [17.85288612],
#        [16.01535962],
#        [16.01535962],
#        [15.94479061],
#        [15.98834111],
#        [15.8809726 ],
#        [15.96707683],
#        [24.90117735],
#        [16.59588368],
#        [21.91932695],
#        [16.36379935],
#        [31.08383284],
#        [19.35970406],
#        [23.29212564],
#        [16.84708481],
#        [23.47620424],
#        [28.99826449],
#        [25.59403986],
#        [23.90596344],
#        [21.05501962],
#        [16.05349147],
# ...

# %%
print ('intercept b:', model.intercept_)
print('model slope m:', model.coef_)
# Out:
# intercept b: [15.84423446]
# model slope m: [[2.24976906]]

# %%
#multiple

# %%
x=
y=
