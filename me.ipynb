# %%
import numpy as np
import pandas as pd
data=pd.read_csv("Fat_Supply_Quantity_Data.csv")
data
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
data.shape
# Out:
# (170, 33)

# %%
data.describe()
# Out:
#        Alcoholic Beverages  Animal Products  Animal fats  \
# count           170.000000       170.000000   170.000000
# mean              0.001035        20.695714     4.138451
# std               0.009569         8.002713     3.287462
# min               0.000000         5.018200     0.026200
# 25%               0.000000        14.885800     1.674225
# 50%               0.000000        20.943050     3.312350
# 75%               0.000000        26.866950     6.227575
# max               0.097600        36.901800    14.937300
#
#        Aquatic Products, Other  Cereals - Excluding Beer        Eggs  \
# count               170.000000                170.000000  170.000000
# mean                  0.000450                  4.376548    0.953890
# std                   0.004039                  3.183815    0.643957
# min                   0.000000                  0.990800    0.058000
# 25%                   0.000000                  1.970150    0.411350
# ...

# %%
data.values
# Out:
# array([['Afghanistan', 0.0, 21.6397, ..., 38928000.0, '%',
#         3.006185778873818],
#        ['Albania', 0.0, 32.0002, ..., 2838000.0, '%', 3.0509513742071883],
#        ['Algeria', 0.0, 14.4175, ..., 44357000.0, '%',
#         3.0065581531663548],
#        ...,
#        ['Yemen', 0.0, 12.5401, ..., 29826000.0, '%', 3.002061959364313],
#        ['Zambia', 0.0783, 9.6005, ..., 18384000.0, '%',
#         3.0045637510879026],
#        ['Zimbabwe', 0.0, 10.3796, ..., 14863000.0, '%',
#         3.0088542017089415]], dtype=object)

# %%
data.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                  0.0          21.6397       6.2224
# 1              Albania                  0.0          32.0002       3.4172
# 2              Algeria                  0.0          14.4175       0.8972
# 3               Angola                  0.0          15.3041       1.3130
# 4  Antigua and Barbuda                  0.0          27.7033       4.6686
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                    8.0353  0.6859         0.0327
# 1                      0.0                    2.6734  1.6448         0.1445
# 2                      0.0                    4.2035  1.2171         0.2008
# 3                      0.0                    6.5545  0.1539         1.4155
# 4                      0.0                    3.2153  0.3872         1.5263
#
# ...

# %%
data.head(10)
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                  0.0          21.6397       6.2224
# 1              Albania                  0.0          32.0002       3.4172
# 2              Algeria                  0.0          14.4175       0.8972
# 3               Angola                  0.0          15.3041       1.3130
# 4  Antigua and Barbuda                  0.0          27.7033       4.6686
# 5            Argentina                  0.0          30.3572       3.3076
# 6              Armenia                  0.0          29.6642       6.2619
# 7            Australia                  0.0          24.1099       4.6030
# 8              Austria                  0.0          27.8268      12.8517
# 9           Azerbaijan                  0.0          32.1198       7.7987
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                    8.0353  0.6859         0.0327
# ...

# %%
data.tail(10)
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 160         United Republic of Tanzania               0.0000           7.5907
# 161            United States of America               0.0000          21.2045
# 162                             Uruguay               0.0000          25.5069
# 163                          Uzbekistan               0.0000          25.9903
# 164                             Vanuatu               0.0000          14.9179
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
#      Animal fats  Aquatic Products, Other  Cereals - Excluding Beer    Eggs  \
# ...

# %%
data.sample(n=5)
# Out:
#           Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 30          China               0.0000          31.0465       3.4468
# 145        Sweden               0.0000          28.4111       9.7148
# 97          Malta               0.0000          29.3856       6.6557
# 82   Korea, South               0.0976          20.0483       4.2523
# 144      Suriname               0.0000          14.8751       0.7849
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 30                    0.0097                    2.5989  2.3066         0.9817
# 145                   0.0000                    1.9481  1.3741         0.8778
# 97                    0.0000                    4.8786  1.3878         1.3074
# 82                    0.0511                    1.8403  1.3524         1.9147
# 144                   0.0000                    3.1593  0.9601         0.7720
#
#      Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  \
# ...

# %%
data.sample(frac=.5)
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 165  Venezuela (Bolivarian Republic of)                  0.0          16.3261
# 47                             Eswatini                  0.0          20.8055
# 40                             Djibouti                  0.0          11.1065
# 90                            Lithuania                  0.0          32.3048
# 50                              Finland                  0.0          36.7250
# ..                                  ...                  ...              ...
# 109                       New Caledonia                  0.0          22.2697
# 66                              Hungary                  0.0          28.9972
# 131                               Samoa                  0.0          21.6806
# 99                            Mauritius                  0.0          12.8934
# 120                                Peru                  0.0          18.0402
#
# ...

# %%
data['Country']
# Out:
# 0                             Afghanistan
# 1                                 Albania
# 2                                 Algeria
# 3                                  Angola
# 4                     Antigua and Barbuda
#                       ...
# 165    Venezuela (Bolivarian Republic of)
# 166                               Vietnam
# 167                                 Yemen
# 168                                Zambia
# 169                              Zimbabwe
# Name: Country, Length: 170, dtype: object

# %%
data.loc[:11,['Animal Products','Animal fats']]
# Out:
#     Animal Products  Animal fats
# 0           21.6397       6.2224
# 1           32.0002       3.4172
# 2           14.4175       0.8972
# 3           15.3041       1.3130
# 4           27.7033       4.6686
# 5           30.3572       3.3076
# 6           29.6642       6.2619
# 7           24.1099       4.6030
# 8           27.8268      12.8517
# 9           32.1198       7.7987
# 10          30.2259       4.5600
# 11           9.8365       1.2369

# %%
data.loc[10:15,'Eggs':'Fish, Seafood']
# Out:
#       Eggs  Fish, Seafood
# 10  1.2829         1.4991
# 11  1.2664         2.1646
# 12  1.2130         1.8060
# 13  1.5772         0.5151
# 14  1.1703         0.6188
# 15  0.6759         0.4155

# %%
data.Meat.unique()
# Out:
# array([ 6.1244,  8.7428,  3.8961, 11.0268, 14.3202, 19.2693, 10.8165,
#        11.6002,  8.1099, 11.9993, 17.4941,  1.8407, 13.1382, 11.5636,
#         5.6817, 10.3435,  3.2849, 21.1476,  9.6957,  3.4759, 14.292 ,
#         9.3523,  3.5741,  9.9204, 11.7799,  3.3685,  7.8211, 12.9144,
#         7.8546, 20.2172, 21.6062, 11.3996,  9.6514,  5.6449,  2.5809,
#        11.4896, 16.0233, 10.5506,  8.6212,  9.2408,  5.121 , 13.7339,
#         7.3718,  8.7453,  6.4678,  6.6547, 10.4279, 11.1162,  4.1768,
#         8.423 , 16.6649, 11.0864, 14.0782, 13.4068,  1.3488,  7.2326,
#         8.9127,  3.1618,  6.6267, 12.9576,  7.0735,  2.8993,  8.0527,
#        12.555 ,  7.8944,  7.8603, 10.0576, 13.6029,  0.9061,  3.6237,
#         6.1724,  3.5164, 10.0477,  8.1541,  8.7134,  9.5156,  7.8331,
#         5.8122,  9.674 ,  6.5654,  6.1955,  8.7179, 11.186 ,  9.5706,
#        10.1776, 15.0283,  9.7976,  5.1361,  9.1881,  6.0051, 14.2134,
# ...

# %%
data.Meat.nunique()
# Out:
# 170

# %%
data['mode']=data.Deaths +3
data
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
data[["Animal fats","Animal Products"]].sort_values(by="Animal Products",ascending=False)
# Out:
#      Animal fats  Animal Products
# 101       5.5153          36.9018
# 50        6.3787          36.7250
# 39       14.2498          35.4131
# 67        7.1086          34.4402
# 110      13.9753          34.1264
# ..           ...              ...
# 54        0.2548           6.0418
# 136       0.1678           5.9931
# 34        0.2726           5.3253
# 151       0.5351           5.3063
# 113       0.8078           5.0182
#
# [170 rows x 2 columns]

# %%
data.query('Animal fats>4000' and 'Obesity==22.3' )[["Animal fats","Animal Products"]]
# Out:
#     Animal fats  Animal Products
# 1        3.4172          32.0002
# 20       4.3627          24.8515

# %%
data.filter(like='55',axis=0)
# Out:
#           Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 55        Georgia                  0.0          25.2749       7.2612
# 155  Turkmenistan                  0.0          32.6886       6.4856
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 55                       0.0                    4.5695  1.1781         0.4284
# 155                      0.0                    2.9938  1.1060         0.1274
#
#      Fruits - Excluding Wine     Meat  ...  Vegetables  Obesity  \
# 55                    0.2071   7.2326  ...      0.1999     23.3
# 155                   0.3069  17.4764  ...      0.4459     17.5
#
#      Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 55              7.9   7.042261  0.087995   6.805249  0.149017   3715000.0
# 155             5.4        NaN       NaN        NaN       NaN   6031000.0
#
#      Unit (all except Population)      mode
# 55                              %  3.087995
# ...

# %%
data.where(data.Obesity>20,'Noooo')
# Out:
#                                 Country Alcoholic Beverages Animal Products  \
# 0                                 Noooo               Noooo           Noooo
# 1                               Albania                 0.0         32.0002
# 2                               Algeria                 0.0         14.4175
# 3                                 Noooo               Noooo           Noooo
# 4                                 Noooo               Noooo           Noooo
# ..                                  ...                 ...             ...
# 165  Venezuela (Bolivarian Republic of)                 0.0         16.3261
# 166                               Noooo               Noooo           Noooo
# 167                               Noooo               Noooo           Noooo
# 168                               Noooo               Noooo           Noooo
# 169                               Noooo               Noooo           Noooo
#
# ...

# %%
data.duplicated(subset="Alcoholic Beverages")
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 165     True
# 166     True
# 167     True
# 168    False
# 169     True
# Length: 170, dtype: bool

# %%
data.drop_duplicates(subset="Alcoholic Beverages")
# Out:
#           Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0     Afghanistan               0.0000          21.6397       6.2224
# 82   Korea, South               0.0976          20.0483       4.2523
# 168        Zambia               0.0783           9.6005       1.6113
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                     0.0000                    8.0353  0.6859         0.0327
# 82                    0.0511                    1.8403  1.3524         1.9147
# 168                   0.0000                   14.3225  0.6266         1.0070
#
#      Fruits - Excluding Wine     Meat  ...  Vegetables  Obesity  \
# 0                     0.4246   6.1244  ...      0.3593      4.5
# 82                    0.1766  11.1860  ...      0.6924      4.9
# 168                   0.1343   4.9010  ...      0.1567      6.5
#
#      Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# ...

# %%
data.drop_duplicates(subset="Alcoholic Beverages").sum()
# Out:
# Country                         AfghanistanKorea, SouthZambia
# Alcoholic Beverages                                    0.1759
# Animal Products                                       51.2885
# Animal fats                                            12.086
# Aquatic Products, Other                                0.0511
# Cereals - Excluding Beer                              24.1981
# Eggs                                                   2.6649
# Fish, Seafood                                          2.9544
# Fruits - Excluding Wine                                0.7355
# Meat                                                  22.2114
# Miscellaneous                                          0.0387
# Milk - Excluding Butter                               10.6945
# Offals                                                 0.6427
# Oilcrops                                              12.8281
# Pulses                                                 0.2929
# ...

# %%
data
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
data =pd.copy()
data['Sales'].apply(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-fce81af347d8> in <module>
# ----> 1 data =pd.copy()
#       2 data['Sales'].apply(float)
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'copy'

# %%
imputed_values=my_imputer.fit_transform(cols)
imputed_values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-ae5c5e84665d> in <module>
# ----> 1 imputed_values=my_imputer.fit_transform(cols)
#       2 imputed_values
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     286         self : SimpleImputer
#     287         """
# --> 288         X = self._validate_input(X, in_fit=True)
#     289
#     290         # default fill_value is 0 for numerical input and "missing_value"
#
# ...

# %%
data.drop(["Undernourished"],axis=1,inplace=True)
data
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
imputed_values=my_imputer.fit_transform(cols)
imputed_values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-ae5c5e84665d> in <module>
# ----> 1 imputed_values=my_imputer.fit_transform(cols)
#       2 imputed_values
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     286         self : SimpleImputer
#     287         """
# --> 288         X = self._validate_input(X, in_fit=True)
#     289
#     290         # default fill_value is 0 for numerical input and "missing_value"
#
# ...

# %%
new_values=pd.DataFrame(imputed_values)
new_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-154-14e47ee72d60> in <module>
# ----> 1 new_values=pd.DataFrame(imputed_values)
#       2 new_values
#
# NameError: name 'imputed_values' is not defined
